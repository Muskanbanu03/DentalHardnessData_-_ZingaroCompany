# %% [markdown]
# ###Importing necessary libraries

# %%
#Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

#Library to help with statistical analysis
import scipy.stats as stats

# %% [markdown]
# ## **problem 1**

# %% [markdown]
# A physiotherapist with a male football team is interested in studying the relationship between foot injuries and the positions at which the players play from the data collected.
# Based on the above data, answer the following questions.
#
# 1.1 What is the probability that a randomly chosen player would suffer an injury?
#
# 1.2 What is the probability that a player is a forward or a winger?
#
# 1.3 What is the probability that a randomly chosen player plays in a striker position and has a foot injury?
#
# 1.4 What is the probability that a randomly chosen injured player is a striker?

# %% [markdown]
# ### **1.1) What is the probability that a randomly chosen player would suffer an injury?**

# %%
#finding the probability that a randomly chosen player would suffer an injury
injured_player_probability=round(145/235,4)
injured_player_probability

# %% [markdown]
# *  The probability that a randomly chosen player would suffer an injury is 61.7%

# %% [markdown]
# ### **1.2) What is the probability that a player is a forward or a winger?**

# %%
#finding the probability that a player is a forward
forward_player_probability=(94/235)
print(forward_player_probability)
#finding the probability that a player is a winger
winger_player_probability=round(29/235,4)
print(winger_player_probability)
#finding the probability that a player is a forward or a winger
forward_or_winger_probability=round(123/235,4)
print(forward_or_winger_probability)

# %% [markdown]
# *  The probability that a player is a forward is 40%
# * The probability that a player is a winger is 12.34%
# * The probability that a player is a forward or a winger is 52.34%

# %% [markdown]
# ### **1.3) What is the probability that a randomly chosen player plays a striker position and has a foot injury?**

# %%
#finding the probability that a randomly chosen player plays a striker position and has a foot injury
injured_striker_probability=round(45/235,4)
print(injured_striker_probability)

# %% [markdown]
# *  The probability that a randomly chosen player plays a striker position and has a foot injury is 19.15%

# %% [markdown]
# ### **1.4) What is the probability that a randomly chosen injured player is a striker?**

# %%
#finding the probability that a randomly chosen injured player is a striker
striker_probability=round(45/145,4)
striker_probability

# %% [markdown]
# *  The probability that a randomly chosen injured player is a striker is 31.03%

# %% [markdown]
# ## **Problem 2**

# %% [markdown]
# The breaking strength of gunny bags used for packaging cement is normally distributed with a mean of 5 kg per sq. centimeter and a standard deviation of 1.5 kg per sq. centimeter. The quality team of the cement company wants to know the following about the packaging material to better understand wastage or pilferage within the supply chain; Answer the questions below based on the given information; (Provide an appropriate visual representation of your answers, without which marks will be deducted)
#
# 2.1 What proportion of the gunny bags have a breaking strength of less than 3.17 kg per sq cm?
#
# 2.2 What proportion of the gunny bags have a breaking strength of at least 3.6 kg per sq cm.?
#
# 2.3 What proportion of the gunny bags have a breaking strength between 5 and 5.5 kg per sq cm.?
#
# 2.4 What proportion of the gunny bags have a breaking strength NOT between 3 and 7.5 kg per sq cm.?

# %% [markdown]
# ### **2.1) What proportion of the gunny bags have a breaking strength of less than 3.17 kg per sq cm?**

# %% [markdown]
# * Suppose $X$ is the random variable that denotes the time of effect of a dose. We are to calculate $P(X<3.17)$
#
# * Now, for continuous probability distributions
#
# $$P(X<k) = P(X<=k)$$
#
# * We will use `norm.cdf()` to calculate the cumulative probability
#   * The function `norm.cdf(x, mu, sigma)` calculates the probability $P(X<x)$ or $P(X<=x)$

# %%
mean=5#mean break strenght in kg per sq cm
std_dev=1.5#standard deviation in kg per sq cm

# %%
#finding what proportion of the gunny bags have a breaking strenght of less than 3.17 kg per sq cm
from scipy.stats import norm
prob_lessthan_3_17= norm.cdf(3.17, loc=mean , scale=std_dev)
print('The probability that the time of effect of a dose is less than 3.17 is', round(prob_lessthan_3_17,4))

# %% [markdown]
# *  11.12% is the probability that the time of effect of a dose is less than 3.17

# %% [markdown]
# ### **2.2) What proportion of the gunny bags have a breaking strength of at least 3.6 kg per sq cm.?**

# %%
#finding what probability of the gunny bags have a breaking strength of at least 3.6kg per sq cm
prob_atleast_3_6=1-norm.cdf(3.6,loc=mean,scale=std_dev)
print('The probability of the gunny bags have a breaking strenght of at least 3.6kg per sq cm is',round(prob_atleast_3_6,4))

# %% [markdown]
# *   82.47% is the probability of the gunny bags have a breaking strenght of at least 3.6 kg per sq cm.

# %% [markdown]
# ###**2.3) What proportion of the gunny bags have a breaking strength between 5 and 5.5 kg per sq cm.?**

# %%
#finding what proportion of the gunny bags have a breaking strenght between 5 and 5.5 kg per sq cm
prob=norm.cdf(5.5,loc=mean,scale=std_dev)-norm.cdf(5,loc=mean,scale=std_dev)
print('The probability of the gunny bags have a breaking strenght between 5 and 5.5 kg per sq cm is',round(prob,4))

# %% [markdown]
# *  13.06% is the probability of the gunny bags have a breaking strenght between 5 and 5.5 kg sq cm.

# %% [markdown]
# ###**2.4) What proportion of the gunny bags have a breaking strength NOT between 3 and 7.5 kg per sq cm.?**

# %%
#finding the proportiion of the gunny bags have a breaking strength not between 3 and 7.5 kg per sq cm
proportion=norm.cdf(3,loc=mean,scale=std_dev)+(1-norm.cdf(7.5,loc=mean,scale=std_dev))
print('The probability of the gunny bags have a breaking strength not between 3 and 7.5kg per sq cm',round(proportion,4))

# %% [markdown]
# * 13.9% is the probability of the gunny bags have a breaking strength not between 3 and 7.5kg per sq cm.

# %% [markdown]
# ## **Problem 3**

# %% [markdown]
# Zingaro stone printing is a company that specializes in printing images or patterns on polished or unpolished stones. However, for the optimum level of printing of the image, the stone surface has to have a Brinell's hardness index of at least 150. Recently, Zingaro has received a batch of polished and unpolished stones from its clients. Use the data provided to answer the following (assuming a 5% significance level);
#
# 3.1 Zingaro has reason to believe that the unpolished stones may not be suitable for printing. Do you think Zingaro is justified in thinking so?
#
# 3.2 Is the mean hardness of the polished and unpolished stones the same?

# %%
#Loading csv file
data=pd.read_csv('/content/Zingaro_Company.csv')
#extracting first 5 rows
data.head()

# %%
#checking the shape of the dataset
data.shape

# %% [markdown]
# *  These above are 5 columns of datasets of Zingaro company

# %%
#finding the columns of the datasets
print(data.columns)

# %% [markdown]
# *  There are two rows in the zingaro company dataset

# %%
data.info()

# %% [markdown]
# There are two  in the datasets
# *  unpolished - having 75 rows which are float
# *  Treated and polished - having 75 rows which are float

# %%
data.describe()

# %% [markdown]
# *  Mean : mean of the unploshed column is 134.11 whereas mean of the treated and polished is 147.78
# *  standard deviation : std deviation of unpolished is 33.04 and std deviation of treated and polished

# %%
#checking whether there is null in the datasets
data.isnull().sum()

# %% [markdown]
# *  There is no null values in the datasets

# %%
#checking whether there is duplicates in the dataset or not
data.duplicated().sum()

# %% [markdown]
# *  There is no duplicate values in datasets

# %%
print('Unpolished 'in data.columns)

# %% [markdown]
# ## **3.1 Zingaro has reason to believe that the unpolished stones may not be suitable for printing. Do you think Zingaro is justified in thinking so?**

# %% [markdown]
# ### Step 1: Define null and alternative hypotheses
# Let's frame the null and alternative hypothesis based on the above claim can be formulated as:
#
# **H0**:
#  The mean hardness of unpolished stones is greater than 150 .
#
# **Ha**:
#  The mean hardness of treated and polished is less than 150.
#
# Let μ
#  be the mean hardness of printing stone
#
# Mathematically, the above formulated hypotheses can be written as:
#
# **H0:μ>=150**
#
#
# **Ha:μ<150**
#
# **CHECKING ASSUMPTIONS OF HYPOTHESIS TEST**
#    - The data is approximately normally distributed.
#    - Observations are independent.
#    - The sample size is more than 30.
#    - Unknown population standard deviation.
#
# ### Step 2: Select Appropriate test
# This is a case of a one-tailed test for the significance of a single mean. As the population standard deviation is unknown, a one-sample t-test will be appropriate to test the formulated hypotheses.
#
# In a one sample t-test, we compare a sample mean with a hypothesized population mean to check if the sample mean differs significantly from the population mean.
#
# We are provided that the sample is randomly selected and we assume that it has come from a normally distributed population.
#
# ### Step 3: Decide the significance level
# Let's set the level of significane (alpha) as 0.05
#
# ### Step 4: Calculate the p-value
# We will use the ttest_1samp() function from the scipy.stats library to perform a one-sample t-test.
# The ttest_1samp() function takes the sample observations, hypothesized population mean and the direction of the alternative hypothesis as input and returns the test statistic and the p-value for the test.
# The sample observations are the values of hardness of the printing stone in the dataset.
# The hypotheisized population mean, as provided in the problem statement and defined in the formulated hypotheses is 150
# As it is a one-tailed test towards the right, we will set the argument alternative = 'lesser'

# %%
# plot the distribution plot of engagement-time
print('Sample mean:', np.round(data['Unpolished '].mean(),2))
sns.displot(data=data,x='Unpolished ')
plt.show()

# %%
#Finding whether Zingaro's belief that the unpolished stones may not be suitable for printing is correct or not.
#One-sampel ttest
mu=150#threshold hardness level
test_stat,p_value=stats.ttest_1samp(data['Unpolished '],mu, alternative='less')
print('The P_value is :',p_value)

# %% [markdown]
# **Note**: The type of test (one-tailed) has an effect on the p-value. The alternative argument is set to 'less' as our alternative hypothesis states that mean hardness of zingaro printing stone is less than 150 .

# %% [markdown]
# ### Step 5: Compare the p-value with $\alpha$

# %%
# print the conclusion based on p-value
if p_value < 0.05:
    print(f'As the p-value {p_value} is less than the level of significance, we reject the null hypothesis.')
else:
    print(f'As the p-value {p_value} is greater than the level of significance, we fail to reject the null hypothesis.')

# %% [markdown]
# ### Step 6: Draw Inference

# %% [markdown]
# Since the p-value is less than the 5% significance level, we reject the null hypothesis. Hence, we have enough statistical evidence to say that the mean hardness of the printing stone is lesser than 150 which means that the unpolished stones are not suitable for printing.

# %% [markdown]
# ## **3.2) Is the mean hardness of the polished and unpolished stones the same?**

# %% [markdown]
# ### Step 1: Define null and alternative hypotheses

# %% [markdown]
# **Let's formulate the null and alternative hypothesis for the above problem**

# %% [markdown]
# $H_0:$ The mean hardness of the polished and unpolished stones are the same.
#
# $H_a:$ The mean hardness of the polished and unpolished stones are not same.
#
# Mathematically, the above formulated hypotheses can be written as:
#
# **H0:μ=150**
#
# **Ha:μ !=150**
#
# **CHECKING ASSUMPTIONS OF HYPOTHESIS TEST:**
#
# * The data is approximately normally distributed.
# * Observations are independent.
# * The sample size is more than 30.
# * Unknown population standard deviation.

# %% [markdown]
# ### Step 2: Select Appropriate test

# %% [markdown]
# This is an independent two sample t-test .The null hypothesis *Ho* is that the mean hardness of polished stones equals the mean hardness of unpolished stones, and the alternative hypothesis *Ha* is that they are not equal(two-tailed test)

# %% [markdown]
# ### Step 3: Decide the significance level

# %% [markdown]
# Let's set the level of significane (alpha) as 0.05

# %% [markdown]
# ### Step 4: Calculate the p-value

# %%
#Testing whether the mean hardness of the polished and unpolished stones the same
#Two-sample t-test
test_stat,p_value=stats.ttest_ind(data['Unpolished '],data['Treated and Polished'],equal_var=True,alternative='two-sided')
print(p_value)

# %% [markdown]
# **Note**: The type of test (two-tailed) has an effect on the p_value. the alternative argument is set to 'two-equal' as our alternative hypothesis states that the hardness of polished stones are not equal to the unpolished stones.

# %% [markdown]
# ### Step 5: Compare the p-value with $\alpha$

# %%
# print the conclusion based on p-value
if p_value < 0.05:
    print(f'As the p-value {p_value} is less than the level of significance, we reject the null hypothesis.')
else:
    print(f'As the p-value {p_value} is greater than the level of significance, we fail to reject the null hypothesis.')

# %% [markdown]
# ### Step 6:  Draw inference

# %% [markdown]
# Since the p-value is less than the 5% significance level, we reject the null hypothesis. Hence, we have enough statistical evidence to say that the mean hardness of polished and unpolished stones are not same.

# %% [markdown]
# ## **Actionable Insights and Conclusions**

# %% [markdown]
# - From the sample data, we observed that
#   - we have enough statistical evidence to say that the unpolished stones are not suitable for printing.
#   - The mean hardness of polished and unpolished stones are not same.
#
# - There is enough statistical evidence (p-value of 4.171286997419652e-05 at 5% level of significance) to conclude that the mean hardness of the printing stone is lesser than 150 which shows that the unpolished stones are unsuitable for printing
#
# - There is a difference in the mean hardness between polished and unpolished stones (p-value of 0.00146 at 5% level of significance) to conclude that the mean hardness of the polished and unpolished stones are not same.

# %% [markdown]
# ****

# %% [markdown]
# ## **Problem 4**

# %% [markdown]
# Dental implant data: The hardness of metal implants in dental cavities depends on multiple factors, such as the method of implant, the temperature at which the metal is treated, the alloy used as well as the dentists who may favor one method above another and may work better in his/her favorite method. The response is the variable of interest.
#
# 4.1 How does the hardness of implants vary depending on dentists?
#
# 4.2 How does the hardness of implants vary depending on methods?
#
# 4.3 What is the interaction effect between the dentist and method on the hardness of dental implants for each type of alloy?
#
# 4.4 How does the hardness of implants vary depending on dentists and methods together?

# %% [markdown]
# ###Loading the datasets

# %%
dentist=pd.read_excel('/content/Dental+Hardness+data.xlsx')
dentist.head()

# %%
dentist.info()

# %%
dentist.describe().T

# %%
print(dentist.columns)

# %%
dentist.shape

# %%
dentist.isnull().sum()

# %%
dentist.duplicated().sum()

# %% [markdown]
# The analysis of the hardness of dental implant based on dentists methods ,and other factors involves statistical techniques like **analysis of variance (ANOVA)** , especially if the data is categorical ,and regression modeling . Below are the steps and insights for each question

# %%
#filter data by alloy type1
alloy1 = dentist[dentist['Alloy']==1]
#filter data by alloy type2
alloy2 = dentist[dentist['Alloy']==2]

# %%
#importing necessary libraries
from scipy.stats import levene
#levene test to know whether the population variance are equal or not
groups=[group['Response'].values for name,group in alloy1.groupby('Dentist')]
#perform levene's test
stat,p_value = levene(*groups)
print(f"levene's Test Statistic: {stat},p_value:{p_value}")

#levene test to know whether the population variance are equal or not
groups_method=[group['Response'].values for name,group in alloy1.groupby('Method')]
#perform levene's test
stat,p_value = levene(*groups_method)
print(f"levene's Test Statistic: {stat},p_value:{p_value}")

# %% [markdown]
# ### **4.1 How does the hardness of implants vary depending on dentists?**

# %% [markdown]
# ### Step 1: Define null and alternative hypotheses

# %% [markdown]
# **Let's formulate the null and alternative hypothesis for the above problem**

# %% [markdown]
# $H_0:$ There is no significant difference in the mean hardness across dentists.
#
# $H_a:$ There is a significant difference in the mean hardness across dentists.
#
#
#
# **CHECKING ASSUMPTIONS OF HYPOTHESIS TESTS**
#
#  - The populations are normally distributed
#  - Samples are independent simple random samples
#  - Population variances are equal

# %% [markdown]
# ### Step 2: Select Appropriate test

# %% [markdown]
# To examine the variability in hardness based on dentists:
#   - perform a **One way ANOVA** , where the factor is the dentist(categorical variable)
#   - Investigating the means for each dentist and calculate the F-statistic

# %% [markdown]
# ### Step 3: Decide the significance level

# %% [markdown]
# Let's set the level of significane (alpha) as 0.05

# %% [markdown]
# ### Step 4: Calculate the p-value

# %%
#mean of different methods used by the dentists
print(dentist.groupby('Dentist')['Response'].mean())

# %%
#ANOVA to test effect of dentists
sns.boxplot(data=dentist,x='Dentist',y='Response')
plt.title('Hardness of implants by dentists',fontsize=15)
plt.show()

# %%
import scipy.stats as stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import statsmodels.formula.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# %%
w,p_value=stats.shapiro(dentist['Dentist'])
print('the p_value is',p_value)

# %%
w,p_value=stats.shapiro(dentist['Response'])
print('the p_value is',p_value)

# %%
#one-way anova
model = ols('Response~C(Dentist)',data= alloy1).fit()
anova_dentist = anova_lm(model)
print('ANOVA Table for Dentist(Alloy 1):')
print(anova_dentist)

# %%
#post hoc test
tukey_dentist = pairwise_tukeyhsd(endog=alloy1['Response'],groups=alloy1['Dentist'],alpha=0.05)
print(tukey_dentist)

# %%
#one-way anova
model = ols('Response~C(Dentist)',data= alloy2).fit()
anova_dentist = anova_lm(model)
print('ANOVA Table for Dentist(Alloy 2):')
print(anova_dentist)

# %%
#post hoc test
tukey_dentist = pairwise_tukeyhsd(endog=alloy2['Response'],groups=alloy2['Dentist'],alpha=0.05)
print(tukey_dentist)

# %%
formula = 'Response~ C(Dentist)+C(Response*Dentist)'
model = ols(formula , data= dentist).fit()
print('ANOVA for Dentist effect:')
aov_table = anova_lm(model)
aov_table

# %% [markdown]
# ### Step 5:  Draw inference

# %% [markdown]
# Since the p-value is less than the 5% significance level, we reject the null hypothesis. Hence, we have enough statistical evidence to say that the mean hardness of across dentist are not same.

# %% [markdown]
# ### **4.2 How does the hardness of implants vary depending on methods?**

# %% [markdown]
# ### Step 1: Define null and alternative hypotheses

# %% [markdown]
# **Let's formulate the null and alternative hypothesis for the above problem**

# %% [markdown]
# $H_0:$ There is no significant difference in the mean hardness across methods.
#
# $H_a:$ There is a significant difference in the mean hardness across methods.
#
#
# **CHECKING ASSUMPTIONS OF HYPOTHESIS TESTS**
#
#  - The populations are normally distributed
#  - Samples are independent simple random samples
#  - Population variances are equal

# %% [markdown]
# ### Step 2: Select Appropriate test

# %% [markdown]
# To examine the variability in hardness based on methods:
#
#   - perfom a **one-way ANOVA** , where the factor is the method of implant.
#   - Analyze the practical implications of method effectiveness.

# %% [markdown]
# ### Step 3: Decide the significance level

# %% [markdown]
# Let's set the level of significane (alpha) as 0.05

# %% [markdown]
# ### Step 4: Calculate the p-value

# %%
w,p_value_method=stats.shapiro(dentist['Method'])
print('the p_value is',p_value)

# %%
#finding how does the hardness of implants vary depending on methods
sns.boxplot(data=dentist,x='Method',y='Response')
plt.title('Hardness of implants by Method')
plt.show()

# %%
#one-way anova
model = ols('Response~C(Method)',data= alloy1).fit()
anova_method = anova_lm(model)
print('ANOVA Table for Method(Alloy 1):')
print(anova_method)

# %%
#post hoc test
tukey_Method = pairwise_tukeyhsd(endog=alloy1['Response'],groups=alloy1['Method'],alpha=0.05)
print(tukey_Method)

# %%
#one-way anova
model = ols('Response~C(Method)',data= alloy2).fit()
anova_method = anova_lm(model)
print('ANOVA Table for Method(Alloy 2):')
print(anova_method)

# %%
#post hoc test
tukey_Method = pairwise_tukeyhsd(endog=alloy2['Response'],groups=alloy2['Method'],alpha=0.05)
print(tukey_Method)

# %%
formula = 'Response~ C(Method)+C(Response*Method)'
model = ols(formula , data= dentist).fit()
print('ANOVA for Method effect:')
aov_table = anova_lm(model)
aov_table

# %% [markdown]
# ### Step 5: Drawing inferences

# %% [markdown]
# Since the p-value is less than the 5% significance level, we reject the null hypothesis. Hence, we have enough statistical evidence to say that the mean hardness of across methods are not same.

# %% [markdown]
# ### **4.3) What is the interaction effect between the dentist and method on the hardness of dental implants for each type of alloy?**

# %% [markdown]
# ### Step 1: Define null and alternative hypotheses

# %% [markdown]
# **Let's formulate the null and alternative hypothesis for the above problem**

# %% [markdown]
# $H_0:$ There is no significant interaction effect between dentist and method for each alloy.
#
# $H_a:$ There is a significant interaction effect between dentist and method for each alloy.
#
#
# **CHECKING ASSUMPTIONS OF HYPOTHESIS TESTS**
#
#  - The populations are normally distributed
#  - Samples are independent simple random samples
#  - Population variances are equal

# %% [markdown]
# ### Step 2: Select Appropriate test

# %% [markdown]
# The analyze the interaction effect:
#
#   - Perform a **Two-way ANOVA**(factors:dentist and method) with an interaction term:
#
#       - model : hardness=dentist+method+(dentist*method)

# %% [markdown]
# ### Step 3: Decide the significance level

# %% [markdown]
# Let's set the level of significane (alpha) as 0.05

# %% [markdown]
# ### Step 4: Calculate the p-value

# %%
#finding the interaction effect between dentist and method for each alloy
sns.catplot(data=dentist,x='Method',y='Response',hue='Dentist',col='Alloy',kind='box')
plt.subplots_adjust(top=0.85)
plt.suptitle('Interaction of dentist and method on hardness by alloy')
plt.show()

# %%
#Anova to test the interaction effect
formula='Response~C(Dentist)*C(Method)*C(Alloy)'
model=ols(formula,data=dentist).fit()
anova_interaction=anova_lm(model)
print('anova for interaction effect',anova_interaction)

# %%
#two way anova
interaction_model=ols('Response~C(Dentist)*C(Method)',data=alloy1).fit()
interaction_anova=anova_lm(interaction_model)
print('Two-way ANOVA (Dentist x Method)for Alloy 1 :')
print(interaction_anova)

# %% [markdown]
# **The p-value in the one of the treatments is greater than $\alpha$(0.05)**

# %%
#two way anova
interaction_model=ols('Response~C(Dentist)*C(Method)',data=alloy2).fit()
interaction_anova=anova_lm(interaction_model)
print('Two-way ANOVA (Dentist x Method)for Alloy 2 :')
print(interaction_anova)

# %% [markdown]
# **The p-value in the two of the treatments is greater than $\alpha$(0.05)**

# %% [markdown]
# **Let us check whether there is any interaction effect between the treatments.**

# %%
sns.pointplot(data=alloy1,x='Method',y='Response',hue='Dentist',dodge=True)
plt.title('interaction plot(Dentist vs Method for Alloy 1)')
plt.show()

# %% [markdown]
# **Still, we can see that there is some sort of interaction between all the treatments. So, we will introduce a new term while performing the Two Way ANOVA.**

# %% [markdown]
# ### Step 6: Drawing conclusion

# %% [markdown]
# Since the p-value is less than the 5% significance level, we reject the null hypothesis. Hence, we have enough statistical evidence to say that there is a significant interaction effect between dentist ,response and method for second alloy and for first alloy p_value is more than significance level for dentist this means there is an interaction effect between method and response.

# %% [markdown]
# ### **4.4) How does the hardness of implants vary depending on dentists and methods together ?**

# %% [markdown]
# ### Step 1: Define null and alternative hypotheses

# %% [markdown]
# **Let's formulate the null and alternative hypothesis for the above problem**

# %% [markdown]
# $H_0:$ There is no significant variation of the hardness of implants vary depending on dentists and methods together.
#
# $H_a:$ There is a significant variation of the hardness of implants vary depending on dentists and methods together.
#
# **CHECKING ASSUMPTIONS OF HYPOTHESIS TESTS**
#
#  - The populations are normally distributed
#  - Samples are independent simple random samples
#  - Population variances are equal

# %% [markdown]
# ### Step 2: Select Appropriate test

# %% [markdown]
# To assess the combined effect of dentists and methods:
#
#   - Use the **Two-way ANOVA** results , focusing on the main effects of dentists and method (ignoring interaction initially).
#   - Assess whether the main effects are significant:
#
#      - If both main effects are significant: Both factors independently influence hardness.
#      - If interaction is significant: The combined effect of dentists and methods must be interpreted carefully.

# %% [markdown]
# ### Step 3: Decide the significance level

# %% [markdown]
# Let's set the level of significane (alpha) as 0.05

# %% [markdown]
# ### Step 4: Calculate the p-value

# %%
sns.boxplot(data=dentist,x='Method',y='Response',hue='Dentist')
plt.title('combined effect of dentist and method on hardness')
plt.show()

# %%
#comprehensive model with both factors
formula='Response~C(Dentist)+C(Method)+C(Dentist):C(Method)'
model=ols(formula,data=dentist).fit()
anova_combined=anova_lm(model)
print('ANOVA for dentists and methods together',anova_combined)

# %%
#two way anova for combined effects
combined_model=ols('Response~C(Dentist)+C(Method)+C(Dentist):C(Method)',data=alloy1).fit()
combined_anova=anova_lm(combined_model)
print('combined ANOVA (Dentist + Method + Interaction)for Alloy 1:')
print(combined_anova)

# %%
#two way anova for combined effects
combined_model=ols('Response~C(Dentist)+C(Method)+C(Dentist):C(Method)',data=alloy2).fit()
combined_anova=anova_lm(combined_model)
print('combined ANOVA (Dentist + Method + Interaction)for Alloy 2:')
print(combined_anova)

# %% [markdown]
# ### Step 5: Drawing inferences

# %% [markdown]
# Since the p-value is less than the 5% significance level, we reject the null hypothesis for first alloy and for second there is not enough evidence to reject the null hypothesis since denist and dentist with method has p_value more than significance level. Hence, we have enough statistical evidence to say that there is a significant variation of the hardness of implants vary depending on dentists and methods together in alloy 1 and for alloy 2 there is no significance variation of the hardness of implants vary depending on dentist and dentist with method.
